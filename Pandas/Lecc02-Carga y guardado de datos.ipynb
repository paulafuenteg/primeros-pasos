# %% [markdown]
# 1- Id cargando todos los ficheros en vuestro jupyter.
# Si os da error leer el pickle será por la versión de pandas. Podéis guardar el csv como pickle y cargarlo de ahí.

# %%
import pandas as pd
import numpy as np
import pickle

# %%
#Archivo csv
df_csv = pd.read_csv('Datos/quejas.csv', sep = ';', encoding = 'Latin 1')
df_csv.head(10)
# Out:
#          tipo                   estado canal_entrada        fecha_entrada  \
# 0       Queja  Recepcionada por Unidad      INTERNET  2022-01-28 00:00:00
# 1       Queja  Recepcionada por Unidad      INTERNET  2022-03-28 00:00:00
# 2       Queja  Recepcionada por Unidad      INTERNET  2022-03-23 00:00:00
# 3       Queja  Recepcionada por Unidad      INTERNET  2022-01-24 00:00:00
# 4       Queja  Recepcionada por Unidad      INTERNET  2022-03-29 00:00:00
# 5  Sugerencia  Contestada al Ciudadano      INTERNET  2022-03-08 00:00:00
# 6       Queja  Contestada al Ciudadano      INTERNET  2022-01-28 00:00:00
# 7  Sugerencia  Contestada al Ciudadano      INTERNET  2022-01-24 00:00:00
# 8       Queja  Recepcionada por Unidad      INTERNET  2022-02-17 00:00:00
# 9       Queja  Contestada al Ciudadano      INTERNET  2022-03-21 00:00:00
#
#     fecha_contestacion                                         consejeria  \
# 0                  NaN  Consejería de Medio Ambiente, Vivienda y Agric...
# ...

# %%
#Archivo excel
df_xlsx = pd.read_excel('Datos/quejas2.xlsx')
df_xlsx.head(10)
# Out:
#             DESCRIPCION_TEMA  \
# 0      ATENCIÓN AL CIUDADANO
# 1      ATENCIÓN AL CIUDADANO
# 2      ATENCIÓN AL CIUDADANO
# 3      ATENCIÓN AL CIUDADANO
# 4      ATENCIÓN AL CIUDADANO
# 5      ATENCIÓN AL CIUDADANO
# 6      ATENCIÓN AL CIUDADANO
# 7      ATENCIÓN AL CIUDADANO
# 8      ATENCIÓN AL CIUDADANO
# 9  ATENCIÓN AL CONTRIBUYENTE
#
#                                  DESCRIPCION_SUBTEMA
# 0                         ADMINISTRACIÓN ELECTRÓNICA
# 1                                    FUNCIÓN PÚBLICA
# 2  OFICINAS DE ATENCIÓN AL CIUDADANO DE LA COMUNI...
# 3     OFICINAS DE REGISTRO DE LA COMUNIDAD DE MADRID
# 4                                              OTROS
# 5                               PORTAL DEL CIUDADANO
# 6           PUNTOS DE INFORMACIÓN EN LAS CONSEJERÍAS
# 7                               SUGERENCIAS Y QUEJAS
# 8                                       TELÉFONO 012
# 9                             DEVOLUCIÓN DE INGRESOS

# %%
#Archivo JSON
df_json = pd.read_json('Datos/quejas.json')
df_json.head(10)
# Out:
#                                                 data
# 0  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 1  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 2  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 3  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 4  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 5  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 6  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 7  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 8  {'unidad_descripcion': 'D.G. de Descarbonizaci...
# 9  {'unidad_descripcion': 'D.G. de Descarbonizaci...

# %%
# Para que sea más legible
df_json2 = df_json['data'].apply(pd.Series)
df_json2.head()
# Out:
#                                  unidad_descripcion   tipo  \
# 0  D.G. de Descarbonización y Transición Energética  Queja
# 1  D.G. de Descarbonización y Transición Energética  Queja
# 2  D.G. de Descarbonización y Transición Energética  Queja
# 3  D.G. de Descarbonización y Transición Energética  Queja
# 4  D.G. de Descarbonización y Transición Energética  Queja
#
#                     estado     tema  \
# 0  Recepcionada por Unidad  ENERGÍA
# 1  Recepcionada por Unidad  ENERGÍA
# 2  Recepcionada por Unidad  ENERGÍA
# 3  Recepcionada por Unidad  ENERGÍA
# 4  Recepcionada por Unidad  ENERGÍA
#
#                                           consejeria fecha_contestacion  \
# 0  Consejería de Medio Ambiente, Vivienda y Agric...
# 1  Consejería de Medio Ambiente, Vivienda y Agric...
# 2  Consejería de Medio Ambiente, Vivienda y Agric...
# 3  Consejería de Medio Ambiente, Vivienda y Agric...
# 4  Consejería de Medio Ambiente, Vivienda y Agric...
#
# ...

# %%
#Archivo pickle
df_pickle = pd.read_pickle('Datos/algas.pickle')
df_pickle.head()
# Out:
#    Unnamed: 0       lon      lat    locality  year  month    kingdom  \
# 0          22  -70.7167  43.0750  New Castle  1900    5.0  Chromista
# 1          23  -70.7167  43.0750  New Castle  1900    5.0  Chromista
# 2          24  -70.7167  43.0750  New Castle  1900    5.0    Plantae
# 3          33 -158.1170  21.5833     Haleiwa  1900    6.0    Plantae
# 4          35   -7.0000  62.1800     Hvalvík  1900    6.0  Chromista
#
#              class        family     genus            species  \
# 0     Phaeophyceae      Fucaceae     Fucus  Fucus vesiculosus
# 1     Phaeophyceae      Fucaceae     Fucus  Fucus vesiculosus
# 2  Florideophyceae  Palmariaceae  Palmaria   Palmaria palmata
# 3      Ulvophyceae      Ulvaceae      Ulva       Ulva lactuca
# 4     Phaeophyceae    Alariaceae    Alaria   Alaria esculenta
#
#                 new             state        country       fecha  day  \
# 0   43.075,-70.7167     New Hampshire  United States  1900-05-01    1
# ...

# %% [markdown]
# 2. Para poner el práctica el read_clipboard elegir alguna tabla que os podaís encontrar en google y usad dicho método para traer los datos al jupyter notebook. Una vez que los hayáis cargado, guardad esos datos en los siguientes formatos:
# - csv
# - excel
# - json
# - pickle

# %%
df_clip = pd.read_clipboard()
df_clip
# Out:
#      Alumno Prácticas  Examen NOTA FINAL
# 0  Alumno 1         6       4          5
# 1  Alumno 2         6       8          7
# 2  Alumno 3      n.p.       8       n.p.
# 3  Alumno 4         9       9          9

# %%
#Guardar a csv
df_clip.to_csv('Datos/tabla.csv')

# %%
#Guardar en excel
df_clip.to_excel('Datos/tabla.xlsx')

# %%
#Guardar en json
df_clip.to_json('Datos/tabla.json')

# %%
#Guardar en pickle
df_clip.to_pickle('Datos/tabla.pickle')
