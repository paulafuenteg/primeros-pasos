# %%
import pandas as pd

# %%
#Leemos el archivo y lo guardamos en la variable pandas 5
attacks5 = pd.read_csv('Datos/attacks_pandas_5.csv')
attacks5.head(2)
# Out:
#     case_number    year        type     country      area location  \
# 0    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne      NaN
# 1  1797.05.28.R  1797.0  Unprovoked         NaN       NaN      NaN
#
#                           activity   name sex_  age time species_  \
# 0  a corsair's boat was overturned    NaN    F  NaN  NaN      NaN
# 1                Dropped overboard  child  NaN  NaN  NaN      NaN
#
#                                                 href     siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
#
#                                      injury                  date
# 0  FATAL, all onboard were killed by sharks                  1800
# 1                                     FATAL  Reported May-28-1797

# %% [markdown]
# 1- ¿Cuántos ataques hubo por país? Devuelve un DataFrame.
#
# 📌 NOTA Ordena los resultados de mayor a menor. Esto todavía no lo hemos visto, pero un DataFrame lo podemos ordenar con .sort_values().

# %%
#Creamos un df con la suma de los ataques por pais
pais = attacks5.groupby('country')['case_number'].agg(ataques=('count')) #Usamos agg para poder cambiarle el nombre a la columna 
pais = pais.reset_index()
pais.head()
# Out:
#           country  ataques
# 0  AMERICAN SAMOA        2
# 1       ARGENTINA        1
# 2           ASIA?        1
# 3       AUSTRALIA      343
# 4         BAHAMAS       29

# %%
#Ordenamos el df por la columna ataques de mayor a menor
pais.sort_values(by='ataques', ascending = False, inplace = True)
pais.head()
# Out:
#          country  ataques
# 91           USA      741
# 3      AUSTRALIA      343
# 78  SOUTH AFRICA      234
# 4        BAHAMAS       29
# 59   NEW ZEALAND       21

# %% [markdown]
# 2- ¿Cuántos ataques ha habido por año? Devuelve un DataFrame. De nuevo ordena los resultados de mayor a menor.

# %%
#Creamos un df con la suma de los ataques por año
año = attacks5.groupby('year')['case_number'].agg(ataques=('count')) 
año = año.reset_index()
año.head()
# Out:
#      year  ataques
# 0     0.0      125
# 1     5.0        1
# 2    77.0        1
# 3   500.0        1
# 4  1543.0        1

# %%
#Ordenamos el df por la columna ataques de mayor a menor
año.sort_values(by='ataques', ascending = False, inplace = True)
año
# Out:
#        year  ataques
# 0       0.0      125
# 143  2015.0       68
# 135  2007.0       57
# 140  2012.0       54
# 130  2002.0       53
# ..      ...      ...
# 33   1784.0        1
# 32   1783.0        1
# 36   1787.0        1
# 30   1779.0        1
# 31   1780.0        1
#
# [147 rows x 2 columns]

# %% [markdown]
# 3- ¿Cuántos ataques hubo por año y sexo? Devolved un DataFrame solo del año 2000 en adelante.

# %%
#Creamos un df con la suma de los ataques por año y por sexo
año_sexo = attacks5.groupby(['year','sex_'])['case_number'].agg(ataques=('count'))
año_sexo= año_sexo.reset_index()
año_sexo.head()
# Out:
#     year sex_  ataques
# 0    0.0    F       13
# 1    0.0    M      104
# 2    5.0    M        1
# 3   77.0    M        1
# 4  500.0    M        1

# %%
#Filtramos por aquellos ocurridos a partir del año 2000
año2000_sexo =año_sexo[año_sexo['year']>=2000.0]
año2000_sexo.head()
# Out:
#        year sex_  ataques
# 157  2000.0    F        7
# 158  2000.0    M       26
# 159  2001.0    F        3
# 160  2001.0    M       26
# 161  2002.0    F        6

# %% [markdown]
# 4- Primero extraed solo las filas que correspondan a USA, AUSTRALIA y SOUTH AFRICA. ¿Cuántos de los ataques fueron letales por sexo? Devuelve un DataFrame.

# %%
#Creamos un df con los ataques ocurridos en USA, AUSTRALIA Y SUDAFRICA
usa_aus_sa = attacks5[attacks5['country'].isin(['USA','AUSTRALIA', 'SOUTH AFRICA'])]
usa_aus_sa.head(2)
# Out:
#   case_number    year        type    country             area       location  \
# 3  1791.00.00  1791.0  Unprovoked  AUSTRALIA  New South Wales   Port Jackson
# 4  1788.05.10  1788.0        Boat  AUSTRALIA  New South Wales  Sydney Harbor
#
#   activity                              name sex_  age time species_  \
# 3      NaN  female, an Australian aboriginal    F  NaN  NaN      NaN
# 4  Fishing                              boat  NaN  NaN  NaN      NaN
#
#                                                 href     siglo fatal_(y/n)  \
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           N
#
#                                              injury         date
# 3                            FATAL, "bitten in two"         1791
# 4  No injury to occupants, shark bit oar and rudder  10-May-1788

# %%
#Filtramos el dataframe por los accidentes que hayan sido fatales(fatal=Y)
fatal = usa_aus_sa[usa_aus_sa['fatal_(y/n)']=='Y']
fatal.head(2)
# Out:
#    case_number    year        type    country             area  \
# 3   1791.00.00  1791.0  Unprovoked  AUSTRALIA  New South Wales
# 10  1780.08.08  1780.0  Unprovoked        USA          Florida
#
#                              location  activity  \
# 3                        Port Jackson       NaN
# 10  Pensacola Harbor, Escambia County  Swimming
#
#                                 name sex_  age time species_  \
# 3   female, an Australian aboriginal    F  NaN  NaN      NaN
# 10                      Joseph Feron    M  NaN  NaN      NaN
#
#                                                  href     siglo fatal_(y/n)  \
# 3   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 10  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
#
#                     injury         date
# 3   FATAL, "bitten in two"         1791
# 10                   FATAL  08-Aug-1780

# %%
#Agrupamos el df fatal por el sexo y contamos los casos por sexo
fatal_genero = fatal.groupby('sex_')['case_number'].agg(ataques=('count'))
fatal_genero= fatal_genero.reset_index()
fatal_genero
# Out:
#   sex_  ataques
# 0    F       20
# 1    M      172

# %% [markdown]
# 5- Usando el DataFrame creado en el ejercicio anterior. ¿En qué país hubo más ataques?

# %%
#Agrupamos el df por país y contamos el número de casos para ver en que país ha habido más
usa_aus_sa.groupby('country')['case_number'].count()
#Un USA hubo más ataques
# Out:
# country
# AUSTRALIA       343
# SOUTH AFRICA    234
# USA             741
# Name: case_number, dtype: int64

# %% [markdown]
# 6- ¿Qué y cuántos tipos de ataques hubo por país?

# %%
#Creamos un df con el número de ataques por país y tipo de ataque
tipo_ataque_pais = usa_aus_sa.groupby(['country', 'type'])['case_number'].agg(ataques=('count')) 
tipo_ataque_pais = tipo_ataque_pais.reset_index()
tipo_ataque_pais
# Out:
#          country          type  ataques
# 0      AUSTRALIA          Boat        1
# 1      AUSTRALIA       Boating        4
# 2      AUSTRALIA       Invalid       18
# 3      AUSTRALIA      Provoked       27
# 4      AUSTRALIA  Sea Disaster        3
# 5      AUSTRALIA    Unprovoked      290
# 6   SOUTH AFRICA       Invalid       10
# 7   SOUTH AFRICA      Provoked       14
# 8   SOUTH AFRICA    Unprovoked      210
# 9            USA       Boating       11
# 10           USA       Invalid       48
# 11           USA      Provoked       49
# 12           USA  Sea Disaster        1
# 13           USA    Unprovoked      632
